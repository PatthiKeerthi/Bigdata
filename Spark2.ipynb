# %% [markdown]
# <a href="https://colab.research.google.com/github/PatthiKeerthi/Bigdata/blob/main/Spark2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Dataframe').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://b99ab3889b96:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df=spark.read.option('header','true').csv('/content/test1.csv',inferSchema=True)
df
# Out:
# DataFrame[Name: string, age: int, Experience: int, Salary: int]

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
df_pyspark=spark.read.csv('/content/test1.csv',header=True,inferSchema=True)
df_pyspark.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df_pyspark.select(['Name','Experience']).show()
# Out:
# +--------+----------+
# |    Name|Experience|
# +--------+----------+
# |     Ben|        10|
# |Srikanth|         8|
# |   Sunny|         4|
# |    Paul|         3|
# |  Harish|         1|
# |   Shiva|         2|
# +--------+----------+

# %%
df_pyspark.select(['age']).show()
# Out:
# +---+
# |age|
# +---+
# | 31|
# | 30|
# | 29|
# | 24|
# | 21|
# | 23|
# +---+

# %%
df_pyspark.filter(df_pyspark['age']<25).show()
# Out:
# +------+---+----------+------+
# |  Name|age|Experience|Salary|
# +------+---+----------+------+
# |  Paul| 24|         3| 20000|
# |Harish| 21|         1| 15000|
# | Shiva| 23|         2| 18000|
# +------+---+----------+------+

# %%
df_pyspark.filter(df_pyspark['Name']=='Ben').show()
# Out:
# +----+---+----------+------+
# |Name|age|Experience|Salary|
# +----+---+----------+------+
# | Ben| 31|        10| 30000|
# +----+---+----------+------+

# %%
df_pyspark.filter((df_pyspark['age']<35) & (df_pyspark['Experience']>5)).show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# +--------+---+----------+------+

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
df_pyspark.describe().show()
# Out:
# +-------+-----+------------------+-----------------+------------------+
# |summary| Name|               age|       Experience|            Salary|
# +-------+-----+------------------+-----------------+------------------+
# |  count|    6|                 6|                6|                 6|
# |   mean| NULL|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev| NULL| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|  Ben|                21|                1|             15000|
# |    max|Sunny|                31|               10|             30000|
# +-------+-----+------------------+-----------------+------------------+

# %%
ord('S')
ord('u') #117
# Out:
# 117

# %%
chr(97)

# %%
df_pyspark.withColumn('Experience after 2 years',df_pyspark['Experience']+2).show()
# Out:
# +--------+---+----------+------+------------------------+
# |    Name|age|Experience|Salary|Experience after 2 years|
# +--------+---+----------+------+------------------------+
# |     Ben| 31|        10| 30000|                      12|
# |Srikanth| 30|         8| 25000|                      10|
# |   Sunny| 29|         4| 20000|                       6|
# |    Paul| 24|         3| 20000|                       5|
# |  Harish| 21|         1| 15000|                       3|
# |   Shiva| 23|         2| 18000|                       4|
# +--------+---+----------+------+------------------------+

# %%
df_pyspark.drop('Experience after 2 years').show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df_pyspark.withColumnRenamed('Name','New Name').show()
# Out:
# +--------+---+----------+------+
# |New Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+
